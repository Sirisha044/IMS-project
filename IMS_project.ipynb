# %%
 import json
 record = { 1001:{"name":"Rice","qn":50,"pr":1000},
           1002:{"name":"sugar","qn":75,"pr":50},
           1003: {"name":"salt","qn":26,"pr":40},
           1004:{"name":"oil","qn":25,"pr":75},
           1005:{"name":"Notebooks","qn":50,"pr":85},
           1006:{"name":"Maggie","qn":75,"pr":20},
           1007:{"name":"Boost","qn":20,"pr":40},
           1008:{"name":"colgate","qn":40,"pr":25},
           1009:{"name":"candy","qn":1000,"pr":5},
           1010:{"name":"pen","qn":100,"pr":20},
           1011:{"name":"phone","qn":10,"pr":50000},
           1012:{"name":"mic","qn":2,"pr":1500},
           1013:{"name":"case","qn":5,"pr":599},
           1014:{"name":"Tomato sauce ","qn":26,"pr":55},
           1015:{"name":"Face cream","qn":10,"pr":25},
           1016:{"name":"Bourbon ","qn":50,"pr":25},
           1017:{"name":"milk shake","qn":10,"pr":20},
           1018:{"name":"Choco cake","qn":34,"pr":100},
           1019:{"name":"Milk cake","qn":78,"pr":800},
           1020:{"name":"Drink","qn":84,"pr":85},
           1021:{"name":"Paint brushes","qn":30,"pr":40},
           1022:{"name":"kitkat","qn":75,"pr":25},
           1023:{"name":"Fevistick","qn":15,"pr":10},
           1024:{"name":"schoolBags","qn":18,"pr":800},
           1025:{"name":"walnuts","qn":10,"pr":100},
           1026:{"name":"Eggs","qn":30,"pr":65},
           1027:{"name":"Bread","qn":45,"pr":98},
           1028:{"name":"sweet corn","qn":15,"pr":45},
           1029:{"name":"apples","qn":60,"pr":40},
           1030:{"name":"waterbottles ","qn":45,"pr":60}  }
 fd=open("record.json",'w')
 js=json.dumps(record)
 fd.write(js)
 fd.close()
 fd=open("record.json",'r')
 r=fd.read()
 fd.close()
 record=json.loads(r) 
 sd=open('sales.json','w')

name=input("Enter your name:")
#declaration
price=0
pricerecord=[]
totalprice=0
Finalfinalprice=0
kart=[]
bill=[]
irecord=[]
qrecord=[]
precord=[]
option=int(input("for list of record press 1:"))
if option==1:
   print(record)
for i in range(len(record)):
   inp1=int(input("if you want to buy press 1 or 2 for billing:"))
   if inp1==2:
     break
   if inp1==1:
     ui_prod=str(input("Enter the product_Id: "))
     ui_quant=int(input("Enter the quantity: "))

     print("product: ",record[ui_prod]['name'])
     print("quantity: ",record[ui_prod]['qn'])
     print("price: ",record[ui_prod]['pr'])
     kart.append(record[ui_prod])
     bill.append(record[ui_prod]['pr']*ui_quant)
     record[ui_prod]['qn']=record[ui_prod]['qn']-ui_quant
sum=0
for j in bill:
  sum+=int(j)
inp=input("can i bill the items yes or no:")  
if inp=='yes':   
     
     print("updated products: ",record[ui_prod]['qn'])
     print("Billing amount: ",sum)
 jd=json.dumps(kart)
 sd.write(jd)
 sd.close()
